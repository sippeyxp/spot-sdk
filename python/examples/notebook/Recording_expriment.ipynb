# %%
import argparse
import cv2
import numpy as np
import os
import pickle
import sys
import time
import traceback

from bosdyn.api import *
from bosdyn.client.estop import EstopClient
from bosdyn.client.frame_helpers import *
from bosdyn.client.image import ImageClient
from bosdyn.client.manipulation_api_client import ManipulationApiClient
from bosdyn.client.robot_command import RobotCommandBuilder, RobotCommandClient, blocking_stand
from bosdyn.client.robot_state import RobotStateClient
import bosdyn.client
import bosdyn.client.estop
import bosdyn.client.lease
import bosdyn.client.util
import bosdyn.geometry

# %%
sdk = bosdyn.client.create_standard_sdk('HelloSpotClient')
robot = sdk.create_robot("192.168.80.3")
robot.authenticate("user", "spot_locomotion")
robot_state_client = robot.ensure_client(RobotStateClient.default_service_name)
#robot_state = robot_state_client.get_robot_state

# Establish time sync with the robot. This kicks off a background thread to establish time sync.
# Time sync is required to issue commands to the robot. After starting time sync thread, block
# until sync is established.
robot.time_sync.wait_for_sync()

# %%
# Record trajectory

#traj = []

for i in range(1000):
    robot_state = robot_state_client.get_robot_state()
    traj.append(robot_state)

with open("recording_1.pkl", "wb") as f:
    pickle.dump(traj, f)

# %%
print(traj[100])
# Out:
# power_state {
#   motor_power_state: STATE_ON
#   shore_power_state: STATE_OFF_SHORE_POWER
#   locomotion_charge_percentage {
#     value: 6.0
#   }
#   locomotion_estimated_runtime {
#     seconds: 377
#     nanos: 773925781
#   }
#   robot_power_state: ROBOT_POWER_STATE_ON
#   payload_ports_power_state: PAYLOAD_PORTS_POWER_STATE_ON
#   wifi_radio_power_state: WIFI_RADIO_POWER_STATE_ON
# }
# battery_states {
#   identifier: "02-21608-002e"
#   charge_percentage {
#     value: 6.0
#   }
#   estimated_runtime {
#     seconds: 377
#     nanos: 773925781
#   }
#   current {
#     value: -6.4800004959106445
#   }
#   voltage {
#     value: 44.94000244140625
#   }
#   temperatures: 40.20695877075195
#   temperatures: 40.0616455078125
#   temperatures: 40.871864318847656
#   temperatures: 40.63408279418945
#   temperatures: 39.703704833984375
#   temperatures: 40.75737380981445
#   temperatures: 40.995155334472656
#   temperatures: 40.75297164916992
#   temperatures: 40.80141067504883
#   temperatures: 40.26420211791992
#   status: STATUS_DISCHARGING
# }
# comms_states {
#   timestamp {
#     seconds: 1651883223
#     nanos: 31167242
#   }
#   wifi_state {
#     current_mode: MODE_ACCESS_POINT
#   }
# }
# comms_states {
#   timestamp {
#     seconds: 1651883222
#     nanos: 998470669
#   }
# }
# system_fault_state {
#   faults {
#     name: "spot_check.fault"
#     onset_timestamp {
#       seconds: 1651876749
#       nanos: 133956864
#     }
#     duration {
#       seconds: 6474
#       nanos: 318289995
#     }
#     code: 3
#     error_message: "SpotCheck has not been run for 163 days. Please run SpotCheck to clear this fault."
#     severity: SEVERITY_INFO
#     uid: 8590067715
#   }
#   faults {
#     name: "battery_fault"
#     onset_timestamp {
#       seconds: 1651883056
#       nanos: 66767104
#     }
#     duration {
#       seconds: 167
#       nanos: 385479927
#     }
#     code: 21
#     error_message: "Battery has low state of charge (6.0%)"
#     attributes: "robot"
#     attributes: "battery"
#     severity: SEVERITY_WARN
#     uid: 8862695445
#   }
#   aggregated {
#     key: "battery"
#     value: SEVERITY_WARN
#   }
#   aggregated {
#     key: "robot"
#     value: SEVERITY_WARN
#   }
# }
# estop_states {
#   timestamp {
#     seconds: 1651883223
#     nanos: 455246848
#   }
#   name: "hardware_estop"
#   type: TYPE_HARDWARE
#   state: STATE_NOT_ESTOPPED
# }
# estop_states {
#   timestamp {
#     seconds: 1651883223
#     nanos: 455246848
#   }
#   name: "payload_estop"
#   type: TYPE_HARDWARE
#   state: STATE_NOT_ESTOPPED
# }
# estop_states {
#   timestamp {
#     seconds: 1651883223
#     nanos: 455246848
#   }
#   name: "software_estop"
#   type: TYPE_SOFTWARE
#   state: STATE_NOT_ESTOPPED
# }
# kinematic_state {
#   joint_states {
#     name: "fl.hx"
#     position {
#       value: 0.5712928175926208
#     }
#     velocity {
#       value: -0.15799885988235474
#     }
#     acceleration {
#       value: -7.592822551727295
#     }
#     load {
#       value: -6.8400044441223145
#     }
#   }
#   joint_states {
#     name: "fl.hy"
#     position {
#       value: 0.8402900695800781
#     }
#     velocity {
#       value: 0.0664004236459732
#     }
#     acceleration {
#       value: 20.062509536743164
#     }
#     load {
#       value: 2.5284388065338135
#     }
#   }
#   joint_states {
#     name: "fl.kn"
#     position {
#       value: -1.6415807008743286
#     }
#     velocity {
#       value: -0.20652078092098236
#     }
#     acceleration {
#       value: -16.729198455810547
#     }
#     load {
#       value: 15.540216445922852
#     }
#   }
#   joint_states {
#     name: "fr.hx"
#     position {
#       value: 0.5248319506645203
#     }
#     velocity {
#       value: -0.10019402951002121
#     }
#     acceleration {
#       value: 24.369670867919922
#     }
#     load {
#       value: 3.206392288208008
#     }
#   }
#   joint_states {
#     name: "fr.hy"
#     position {
#       value: 0.7283814549446106
#     }
#     velocity {
#       value: 0.1303083598613739
#     }
#     acceleration {
#       value: 27.97735023498535
#     }
#     load {
#       value: 0.3480170965194702
#     }
#   }
#   joint_states {
#     name: "fr.kn"
#     position {
#       value: -1.4405055046081543
#     }
#     velocity {
#       value: -0.5785097479820251
#     }
#     acceleration {
#       value: -74.38932037353516
#     }
#     load {
#       value: 9.315875053405762
#     }
#   }
#   joint_states {
#     name: "hl.hx"
#     position {
#       value: 0.563343346118927
#     }
#     velocity {
#       value: -0.215148463845253
#     }
#     acceleration {
#       value: -12.32422924041748
#     }
#     load {
#       value: -6.715872287750244
#     }
#   }
#   joint_states {
#     name: "hl.hy"
#     position {
#       value: 0.8474337458610535
#     }
#     velocity {
#       value: 0.09755236655473709
#     }
#     acceleration {
#       value: 17.60521697998047
#     }
#     load {
#       value: 1.5747393369674683
#     }
#   }
#   joint_states {
#     name: "hl.kn"
#     position {
#       value: -1.6728888750076294
#     }
#     velocity {
#       value: -0.3295454680919647
#     }
#     acceleration {
#       value: -27.07017707824707
#     }
#     load {
#       value: 15.952801704406738
#     }
#   }
#   joint_states {
#     name: "hr.hx"
#     position {
#       value: 0.5241020917892456
#     }
#     velocity {
#       value: -0.11396801471710205
#     }
#     acceleration {
#       value: 22.123884201049805
#     }
#     load {
#       value: 2.8866806030273438
#     }
#   }
#   joint_states {
#     name: "hr.hy"
#     position {
#       value: 0.7429203391075134
#     }
#     velocity {
#       value: 0.11738751828670502
#     }
#     acceleration {
#       value: 25.679794311523438
#     }
#     load {
#       value: 0.44709914922714233
#     }
#   }
#   joint_states {
#     name: "hr.kn"
#     position {
#       value: -1.4625383615493774
#     }
#     velocity {
#       value: -0.5969460606575012
#     }
#     acceleration {
#       value: -64.2707748413086
#     }
#     load {
#       value: 11.216415405273438
#     }
#   }
#   joint_states {
#     name: "arm0.sh0"
#     position {
#       value: 0.0003733634948730469
#     }
#     velocity {
#       value: -0.0001947509590536356
#     }
#     acceleration {
#       value: -1.3974875211715698
#     }
#     load {
#       value: 0.6495664119720459
#     }
#   }
#   joint_states {
#     name: "arm0.sh1"
#     position {
#       value: -3.111755847930908
#     }
#     velocity {
#       value: 0.011290307156741619
#     }
#     acceleration {
#       value: 6.655787467956543
#     }
#     load {
#       value: -1.1817916631698608
#     }
#   }
#   joint_states {
#     name: "arm0.hr0"
#     position {
#     }
#     velocity {
#     }
#     acceleration {
#     }
#     load {
#     }
#   }
#   joint_states {
#     name: "arm0.el0"
#     position {
#       value: 3.1366946697235107
#     }
#     velocity {
#       value: -0.019805973395705223
#     }
#     acceleration {
#       value: 0.16734929382801056
#     }
#     load {
#       value: 1.7190710306167603
#     }
#   }
#   joint_states {
#     name: "arm0.el1"
#     position {
#       value: 1.571420431137085
#     }
#     velocity {
#       value: -0.002880703192204237
#     }
#     acceleration {
#       value: 2.6779990196228027
#     }
#     load {
#       value: -0.24948707222938538
#     }
#   }
#   joint_states {
#     name: "arm0.wr0"
#     position {
#       value: 0.002001166343688965
#     }
#     velocity {
#       value: 0.013880358077585697
#     }
#     acceleration {
#       value: 9.557607650756836
#     }
#     load {
#       value: -0.6288871765136719
#     }
#   }
#   joint_states {
#     name: "arm0.wr1"
#     position {
#       value: -1.570807933807373
#     }
#     velocity {
#       value: -0.005538107827305794
#     }
#     acceleration {
#       value: -0.9585846066474915
#     }
#     load {
#       value: 0.04929688945412636
#     }
#   }
#   joint_states {
#     name: "arm0.f1x"
#     position {
#       value: -0.016701102256774902
#     }
#     velocity {
#       value: 0.024011150002479553
#     }
#     acceleration {
#       value: 1.0711482763290405
#     }
#     load {
#       value: 0.28912651538848877
#     }
#   }
#   velocity_of_body_in_vision {
#     linear {
#       x: 0.006851509213447571
#       y: 0.01182585209608078
#       z: -0.003020628821104765
#     }
#     angular {
#       x: -0.16543971002101898
#       y: -0.0011233910918235779
#       z: -0.07045827805995941
#     }
#   }
#   velocity_of_body_in_odom {
#     linear {
#       x: -0.012777484953403473
#       y: 0.004850246012210846
#       z: -0.0030205748043954372
#     }
#     angular {
#       x: 0.027845174074172974
#       y: -0.1630832403898239
#       z: -0.07045828551054001
#     }
#   }
#   acquisition_timestamp {
#     seconds: 1651883223
#     nanos: 455246848
#   }
#   transforms_snapshot {
#     child_to_parent_edge_map {
#       key: "body"
#       value {
#         parent_tform_child {
#           position {
#           }
#           rotation {
#             w: 1.0
#           }
#         }
#       }
#     }
#     child_to_parent_edge_map {
#       key: "flat_body"
#       value {
#         parent_frame_name: "body"
#         parent_tform_child {
#           position {
#           }
#           rotation {
#             x: 0.24838009476661682
#             y: 0.0008305665105581284
#             z: 0.00021296576596796513
#             w: 0.9686623215675354
#           }
#         }
#       }
#     }
#     child_to_parent_edge_map {
#       key: "gpe"
#       value {
#         parent_frame_name: "odom"
#         parent_tform_child {
#           position {
#             x: -0.5662755370140076
#             y: 2.9882655143737793
#             z: -1.4324122667312622
#           }
#           rotation {
#             x: 0.004095888696610928
#             y: -0.003957767970860004
#             z: -1.6210833564400673e-05
#             w: 0.9999837875366211
#           }
#         }
#       }
#     }
#     child_to_parent_edge_map {
#       key: "hand"
#       value {
#         parent_frame_name: "body"
#         parent_tform_child {
#           position {
#             x: 0.5542041063308716
#             y: 0.0004892652505077422
#             z: 0.2581416368484497
#           }
#           rotation {
#             x: 0.0003163734218105674
#             y: 0.012468824163079262
#             z: 0.0011833535972982645
#             w: 0.9999215006828308
#           }
#         }
#       }
#     }
#     child_to_parent_edge_map {
#       key: "link_wr1"
#       value {
#         parent_frame_name: "body"
#         parent_tform_child {
#           position {
#             x: 0.35869547724723816
#             y: 2.490165934432298e-05
#             z: 0.2630181610584259
#           }
#           rotation {
#             x: 0.0003163734218105674
#             y: 0.012468824163079262
#             z: 0.0011833535972982645
#             w: 0.9999215006828308
#           }
#         }
#       }
#     }
#     child_to_parent_edge_map {
#       key: "odom"
#       value {
#         parent_frame_name: "body"
#         parent_tform_child {
#           position {
#             x: 3.042719841003418
#             y: -0.47479915618896484
#             z: 0.7773455381393433
#           }
#           rotation {
#             x: 0.1929028183221817
#             y: -0.15646682679653168
#             z: 0.6128817200660706
#             w: 0.7501217722892761
#           }
#         }
#       }
#     }
#     child_to_parent_edge_map {
#       key: "vision"
#       value {
#         parent_frame_name: "body"
#         parent_tform_child {
#           position {
#             x: 2.9195895195007324
#             y: 0.3181231617927551
#             z: 0.1707412451505661
#           }
#           rotation {
#             x: -0.005651305895298719
#             y: 0.2483171671628952
#             z: -0.9684840440750122
#             w: -0.018588121980428696
#           }
#         }
#       }
#     }
#   }
# }
# behavior_fault_state {
# }
# foot_state {
#   foot_position_rt_body {
#     x: 0.3169882297515869
#     y: 0.4191797375679016
#     z: -0.3613772690296173
#   }
#   contact: CONTACT_MADE
#   terrain {
#     ground_mu_est: 0.6000000238418579
#     frame_name: "odom"
#     foot_slip_distance_rt_frame {
#       x: -0.00015963846817612648
#       y: -0.0007569597219116986
#       z: -1.3356226190808229e-05
#     }
#     foot_slip_velocity_rt_frame {
#       x: 0.021625865250825882
#       y: 0.04555605351924896
#       z: 0.000771702965721488
#     }
#     ground_contact_normal_rt_frame {
#       x: 0.0026716701686382294
#       y: -0.01820501498878002
#       z: 0.9998307228088379
#     }
#   }
# }
# foot_state {
#   foot_position_rt_body {
#     x: 0.3194766044616699
#     y: 0.12190020084381104
#     z: -0.5269466638565063
#   }
#   contact: CONTACT_MADE
#   terrain {
#     ground_mu_est: 0.6000000238418579
#     frame_name: "odom"
#     foot_slip_distance_rt_frame {
#       x: -0.0006373986252583563
#       y: -0.00017384618695359677
#       z: -1.2875630091002677e-05
#     }
#     foot_slip_velocity_rt_frame {
#       x: -0.006149889435619116
#       y: -0.08716628700494766
#       z: -0.004155673086643219
#     }
#     ground_contact_normal_rt_frame {
#       x: -0.007330060005187988
#       y: -0.04710386320948601
#       z: 0.9988631010055542
#     }
#   }
# }
# foot_state {
#   foot_position_rt_body {
#     x: -0.2739512622356415
#     y: 0.4122915267944336
#     z: -0.35792163014411926
#   }
#   contact: CONTACT_MADE
#   terrain {
#     ground_mu_est: 0.6000000238418579
#     frame_name: "odom"
#     foot_slip_distance_rt_frame {
#       x: 0.0009529624367132783
#       y: 0.0005143395974300802
#       z: 4.997102223569527e-06
#     }
#     foot_slip_velocity_rt_frame {
#       x: 0.010785414837300777
#       y: -0.08341225236654282
#       z: 0.0017064650310203433
#     }
#     ground_contact_normal_rt_frame {
#       x: -0.015218771994113922
#       y: 0.018484367057681084
#       z: 0.9997132420539856
#     }
#   }
# }
# foot_state {
#   foot_position_rt_body {
#     x: -0.2777634859085083
#     y: 0.11927030980587006
#     z: -0.5231912136077881
#   }
#   contact: CONTACT_MADE
#   terrain {
#     ground_mu_est: 0.6000000238418579
#     frame_name: "odom"
#     foot_slip_distance_rt_frame {
#       x: -0.0001356661960016936
#       y: 0.00031077212770469487
#       z: 1.386305029882351e-05
#     }
#     foot_slip_velocity_rt_frame {
#       x: 0.0164853073656559
#       y: -0.08775661140680313
#       z: -0.0019044959917664528
#     }
#     ground_contact_normal_rt_frame {
#       x: 0.09171833842992783
#       y: -0.004380702972412109
#       z: 0.9957754015922546
#     }
#   }
# }
# manipulator_state {
#   stow_state: STOWSTATE_STOWED
#   gripper_open_percentage: 1.0637640953063965
#   estimated_end_effector_force_in_hand {
#     x: 15.34768009185791
#     y: 1.6545685529708862
#     z: 15.438111305236816
#   }
#   velocity_of_hand_in_vision {
#     linear {
#       x: -0.0030215727165341377
#       y: 0.08141917735338211
#       z: 0.027074966579675674
#     }
#     angular {
#       x: -0.157382071018219
#       y: -9.268522262573242e-06
#       z: -0.05418626219034195
#     }
#   }
#   velocity_of_hand_in_odom {
#     linear {
#       x: -0.07986034452915192
#       y: -0.016139954328536987
#       z: 0.027074996381998062
#     }
#     angular {
#       x: 0.02544349431991577
#       y: -0.15531159937381744
#       z: -0.05418626219034195
#     }
#   }
#   carry_state: CARRY_STATE_CARRIABLE_AND_STOWABLE
# }

# %%
# Extract quarternion.
traj_rot =[f.kinematic_state.transforms_snapshot.child_to_parent_edge_map["flat_body"].parent_tform_child.rotation for f in traj]

# %%
class QuaternionWrapper:
    
    def __init__(self, q):
        self._q = q
    def to_quaternion(self):
        return self._q

# %%
# Playback
lease_client = robot.ensure_client(bosdyn.client.lease.LeaseClient.default_service_name)
# lease = lease_client.acquire()
lease = lease_client.take()

with bosdyn.client.lease.LeaseKeepAlive(lease_client):
    robot.logger.info("Powering on robot... This may take several seconds.")
    robot.power_on(timeout_sec=20)
    assert robot.is_powered_on(), "Robot power on failed."
    robot.logger.info("Robot powered on.")
    
    # Tell the robot to stand up. The command service is used to issue commands to a robot.
    # The set of valid commands for a robot depends on hardware configuration. See
    # SpotCommandHelper for more detailed examples on command building. The robot
    # command service requires timesync between the robot and the client.
    robot.logger.info("Commanding robot to stand...")
    command_client = robot.ensure_client(RobotCommandClient.default_service_name)
    blocking_stand(command_client, timeout_sec=10)
    robot.logger.info("Robot standing.")
    time.sleep(1)
    
    for i in range(500):
      cmd = RobotCommandBuilder.synchro_stand_command(
          footprint_R_body=QuaternionWrapper(traj_rot[i]))
      command_client.robot_command(cmd)
      robot.logger.info("Robot standing twisted.")
      #time.sleep(0.01)
# Out:
# Generic exception for  during check-in:
# bosdyn.api.RetainLeaseResponse (LeaseUseError):
#     (resuming check-in)
# Generic exception for  during check-in:
# bosdyn.api.RetainLeaseResponse (LeaseUseError):
#     (resuming check-in)

# %%
# Flip around and upright
lease_client = robot.ensure_client(bosdyn.client.lease.LeaseClient.default_service_name)
# lease = lease_client.acquire()
lease = lease_client.take()

with bosdyn.client.lease.LeaseKeepAlive(lease_client):
    robot.logger.info("Powering on robot... This may take several seconds.")
    robot.power_on(timeout_sec=20)
    assert robot.is_powered_on(), "Robot power on failed."
    robot.logger.info("Robot powered on.")
    
    # Tell the robot to stand up. The command service is used to issue commands to a robot.
    # The set of valid commands for a robot depends on hardware configuration. See
    # SpotCommandHelper for more detailed examples on command building. The robot
    # command service requires timesync between the robot and the client.
    robot.logger.info("Commanding robot to stand...")
    command_client = robot.ensure_client(RobotCommandClient.default_service_name)
    # blocking_stand(command_client, timeout_sec=10)
    robot.logger.info("Robot standing.")
    time.sleep(1)

    # batt_change_command = RobotCommandBuilder.battery_change_pose_command()
    batt_change_command = RobotCommandBuilder.selfright_command()
    command_client.robot_command(batt_change_command)
    
    time.sleep(10)
